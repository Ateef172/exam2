# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Downloads/Boston .csv.csv")

# %%
df.head()
# Out:
#    Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0           1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1           2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2           3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3           4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4           5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
#
#    tax  ptratio   black  lstat  medv
# 0  296     15.3  396.90   4.98  24.0
# 1  242     17.8  396.90   9.14  21.6
# 2  242     17.8  392.83   4.03  34.7
# 3  222     18.7  394.63   2.94  33.4
# 4  222     18.7  396.90   5.33  36.2

# %%
plt.scatter(df["indus"],df["nox"])

# %%
a=df.groupby(["chas","rad"]).size().unstack().plot(kind="bar")

# %%
a=df.groupby(["chas","rad"]).size().unstack().plot()

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# crim          0
# zn            0
# indus         0
# chas          0
# nox           0
# rm            0
# age           0
# dis           0
# rad           0
# tax           0
# ptratio       0
# black         0
# lstat         0
# medv          0
# dtype: int64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
x=df.drop(columns=["medv"])
y=df["medv"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30)

# %%
a=LinearRegression()

# %%
b=a.fit(x_train,y_train)

# %%
pred=b.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error

# %%
a=mean_squared_error(y_test,pred)
print(a)
# Out:
# 26.479646156011768

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,pred)
# Out:
# 0.7269339181830519
